# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass


# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 2 of Set 1 | aranos
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 | kantang
# Processing Record 5 of Set 1 | georgetown
# Processing Record 6 of Set 1 | aklavik
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | saint george
# Processing Record 10 of Set 1 | port alfred
# Processing Record 11 of Set 1 | torbay
# Processing Record 12 of Set 1 | iqaluit
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | vaini
# Processing Record 15 of Set 1 | east london
# Processing Record 16 of Set 1 | ulaanbaatar
# Processing Record 17 of Set 1 | chernomorskiy
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | narsaq
# Processing Record 20 of Set 1 | mar del plata
# Processing Record 21 of Set 1 | tiksi
# Processing Record 22 of Set 1 | srednekolymsk
# Processing Record 23 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 1 | brae
# Processing Record 25 of Set 1 | ixtapa
# Processing Record 26 of Set 1 | kodiak
# Processing Record 27 of Set 1 | voi
# Processing Record 28 of Set 1 | pordenone
# Processing Record 29 of Set 1 | magalia
# Processing Record 30 of Set 1 | karabuk
# Processing Record 31 of Set 1 | oranjemund
# Processing Record 32 of Set 1 | hasaki
# Processing Record 33 of Set 1 | narasannapeta
# Processing Record 34 of Set 1 | haines junction
# Processing Record 35 of Set 1 | faanui
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 1 | liuzhou
# Processing Record 39 of Set 1 | norman wells
# Processing Record 40 of Set 1 | saint-philippe
# Processing Record 41 of Set 1 | mayo
# Processing Record 42 of Set 1 | san patricio
# Processing Record 43 of Set 1 | rikitea
# Processing Record 44 of Set 1 | lalomanu
# City not found. Skipping...
# Processing Record 45 of Set 1 | lavrentiya
# Processing Record 46 of Set 1 | ahipara
# Processing Record 47 of Set 1 | sataua
# City not found. Skipping...
# Processing Record 48 of Set 1 | sirfa
# City not found. Skipping...
# Processing Record 49 of Set 1 | nome
# Processing Record 50 of Set 1 | jamestown
# Processing Record 1 of Set 2 | tianpeng
# Processing Record 2 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 2 | vilyuysk
# Processing Record 4 of Set 2 | victoria
# Processing Record 5 of Set 2 | bengkulu
# Processing Record 6 of Set 2 | mahebourg
# Processing Record 7 of Set 2 | sur
# Processing Record 8 of Set 2 | mataura
# Processing Record 9 of Set 2 | port-gentil
# Processing Record 10 of Set 2 | leh
# Processing Record 11 of Set 2 | alofi
# Processing Record 12 of Set 2 | puerto escondido
# Processing Record 13 of Set 2 | saskylakh
# Processing Record 14 of Set 2 | cabedelo
# Processing Record 15 of Set 2 | albany
# Processing Record 16 of Set 2 | sept-iles
# Processing Record 17 of Set 2 | utiel
# Processing Record 18 of Set 2 | namatanai
# Processing Record 19 of Set 2 | sioux lookout
# Processing Record 20 of Set 2 | tuktoyaktuk
# Processing Record 21 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 2 | naze
# Processing Record 23 of Set 2 | bom jesus
# Processing Record 24 of Set 2 | bayir
# Processing Record 25 of Set 2 | pevek
# Processing Record 26 of Set 2 | saint anthony
# Processing Record 27 of Set 2 | nikolskoye
# Processing Record 28 of Set 2 | lagoa
# Processing Record 29 of Set 2 | karratha
# Processing Record 30 of Set 2 | qinhuangdao
# Processing Record 31 of Set 2 | port lincoln
# Processing Record 32 of Set 2 | san policarpo
# Processing Record 33 of Set 2 | san cristobal
# Processing Record 34 of Set 2 | pundaguitan
# Processing Record 35 of Set 2 | broome
# Processing Record 36 of Set 2 | hobart
# Processing Record 37 of Set 2 | grand-lahou
# Processing Record 38 of Set 2 | choma
# Processing Record 39 of Set 2 | chuy
# Processing Record 40 of Set 2 | cape town
# Processing Record 41 of Set 2 | constantine
# Processing Record 42 of Set 2 | carnarvon
# Processing Record 43 of Set 2 | salalah
# Processing Record 44 of Set 2 | new norfolk
# Processing Record 45 of Set 2 | havoysund
# Processing Record 46 of Set 2 | berdigestyakh
# Processing Record 47 of Set 2 | luderitz
# Processing Record 48 of Set 2 | busselton
# Processing Record 49 of Set 2 | marsa matruh
# Processing Record 50 of Set 2 | kavaratti
# Processing Record 1 of Set 3 | saint-joseph
# Processing Record 2 of Set 3 | zhanaozen
# Processing Record 3 of Set 3 | golyshmanovo
# Processing Record 4 of Set 3 | waipawa
# Processing Record 5 of Set 3 | cabo san lucas
# Processing Record 6 of Set 3 | esmeraldas
# Processing Record 7 of Set 3 | terrace bay
# Processing Record 8 of Set 3 | glubokoe
# City not found. Skipping...
# Processing Record 9 of Set 3 | yellowknife
# Processing Record 10 of Set 3 | terrell
# Processing Record 11 of Set 3 | hofn
# Processing Record 12 of Set 3 | vallenar
# Processing Record 13 of Set 3 | lorengau
# Processing Record 14 of Set 3 | ostrovnoy
# Processing Record 15 of Set 3 | zhanakorgan
# Processing Record 16 of Set 3 | pingzhuang
# Processing Record 17 of Set 3 | avarua
# Processing Record 18 of Set 3 | qaanaaq
# Processing Record 19 of Set 3 | tubruq
# City not found. Skipping...
# Processing Record 20 of Set 3 | hermanus
# Processing Record 21 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 3 | akureyri
# Processing Record 23 of Set 3 | umm lajj
# Processing Record 24 of Set 3 | abu samrah
# Processing Record 25 of Set 3 | bud
# Processing Record 26 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 3 | beyneu
# Processing Record 28 of Set 3 | virginia beach
# Processing Record 29 of Set 3 | urengoy
# Processing Record 30 of Set 3 | airai
# Processing Record 31 of Set 3 | allapalli
# Processing Record 32 of Set 3 | saquena
# Processing Record 33 of Set 3 | raymond terrace
# Processing Record 34 of Set 3 | okhotsk
# Processing Record 35 of Set 3 | maceio
# Processing Record 36 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 3 | dutlwe
# Processing Record 38 of Set 3 | kindu
# Processing Record 39 of Set 3 | yulara
# Processing Record 40 of Set 3 | sakata
# Processing Record 41 of Set 3 | yeppoon
# Processing Record 42 of Set 3 | kavieng
# Processing Record 43 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 3 | nabire
# Processing Record 45 of Set 3 | lebu
# Processing Record 46 of Set 3 | tasiilaq
# Processing Record 47 of Set 3 | dikson
# Processing Record 48 of Set 3 | belaya gora
# Processing Record 49 of Set 3 | cheremshanka
# Processing Record 50 of Set 3 | orange walk
# Processing Record 1 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 4 | conceicao do araguaia
# Processing Record 3 of Set 4 | butaritari
# Processing Record 4 of Set 4 | talaya
# Processing Record 5 of Set 4 | sao joao da barra
# Processing Record 6 of Set 4 | lubango
# Processing Record 7 of Set 4 | churapcha
# Processing Record 8 of Set 4 | bluff
# Processing Record 9 of Set 4 | borazjan
# Processing Record 10 of Set 4 | opuwo
# Processing Record 11 of Set 4 | shache
# Processing Record 12 of Set 4 | el dorado
# Processing Record 13 of Set 4 | drayton valley
# Processing Record 14 of Set 4 | kununurra
# Processing Record 15 of Set 4 | marsh harbour
# Processing Record 16 of Set 4 | kenai
# Processing Record 17 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 4 | sonoma
# Processing Record 19 of Set 4 | ilulissat
# Processing Record 20 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 4 | bambous virieux
# Processing Record 22 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 23 of Set 4 | black river
# Processing Record 24 of Set 4 | esperance
# Processing Record 25 of Set 4 | comodoro rivadavia
# Processing Record 26 of Set 4 | dwarka
# Processing Record 27 of Set 4 | flinders
# Processing Record 28 of Set 4 | nanortalik
# Processing Record 29 of Set 4 | thunder bay
# Processing Record 30 of Set 4 | kaitangata
# Processing Record 31 of Set 4 | rundu
# Processing Record 32 of Set 4 | arraial do cabo
# Processing Record 33 of Set 4 | adolfo lopez mateos
# Processing Record 34 of Set 4 | san andres
# Processing Record 35 of Set 4 | ambon
# Processing Record 36 of Set 4 | huarmey
# Processing Record 37 of Set 4 | upernavik
# Processing Record 38 of Set 4 | barrow
# Processing Record 39 of Set 4 | krutinka
# Processing Record 40 of Set 4 | miri
# Processing Record 41 of Set 4 | leningradskiy
# Processing Record 42 of Set 4 | kashin
# Processing Record 43 of Set 4 | ribeira grande
# Processing Record 44 of Set 4 | laguna
# Processing Record 45 of Set 4 | dolbeau
# City not found. Skipping...
# Processing Record 46 of Set 4 | belmonte
# Processing Record 47 of Set 4 | hami
# Processing Record 48 of Set 4 | hohhot
# Processing Record 49 of Set 4 | effium
# Processing Record 50 of Set 4 | itaituba
# Processing Record 1 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 5 | cidreira
# Processing Record 3 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 5 | miramar
# Processing Record 5 of Set 5 | kingisepp
# Processing Record 6 of Set 5 | yinchuan
# Processing Record 7 of Set 5 | khatanga
# Processing Record 8 of Set 5 | tutoia
# Processing Record 9 of Set 5 | baykit
# Processing Record 10 of Set 5 | lasa
# Processing Record 11 of Set 5 | kirkwood
# Processing Record 12 of Set 5 | longyearbyen
# Processing Record 13 of Set 5 | chokurdakh
# Processing Record 14 of Set 5 | fuerte olimpo
# Processing Record 15 of Set 5 | trincomalee
# Processing Record 16 of Set 5 | palauig
# Processing Record 17 of Set 5 | genhe
# Processing Record 18 of Set 5 | bredasdorp
# Processing Record 19 of Set 5 | stokmarknes
# Processing Record 20 of Set 5 | nemuro
# Processing Record 21 of Set 5 | tomatlan
# Processing Record 22 of Set 5 | la orilla
# Processing Record 23 of Set 5 | huanren
# Processing Record 24 of Set 5 | mutsamudu
# City not found. Skipping...
# Processing Record 25 of Set 5 | filadelfia
# Processing Record 26 of Set 5 | kinlochleven
# Processing Record 27 of Set 5 | broken hill
# Processing Record 28 of Set 5 | klaksvik
# Processing Record 29 of Set 5 | karauzyak
# City not found. Skipping...
# Processing Record 30 of Set 5 | bang saphan
# Processing Record 31 of Set 5 | taltal
# Processing Record 32 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 33 of Set 5 | mackay
# Processing Record 34 of Set 5 | zyryanka
# Processing Record 35 of Set 5 | port augusta
# Processing Record 36 of Set 5 | thompson
# Processing Record 37 of Set 5 | callaway
# Processing Record 38 of Set 5 | batsfjord
# Processing Record 39 of Set 5 | pacific grove
# Processing Record 40 of Set 5 | kruisfontein
# Processing Record 41 of Set 5 | college
# Processing Record 42 of Set 5 | havre-saint-pierre
# Processing Record 43 of Set 5 | mattru
# Processing Record 44 of Set 5 | yushu
# Processing Record 45 of Set 5 | killybegs
# Processing Record 46 of Set 5 | rawlins
# Processing Record 47 of Set 5 | bethel
# Processing Record 48 of Set 5 | bambari
# Processing Record 49 of Set 5 | novovarshavka
# Processing Record 50 of Set 5 | tabou
# Processing Record 1 of Set 6 | pangnirtung
# Processing Record 2 of Set 6 | zabaykalsk
# Processing Record 3 of Set 6 | chernyshevskiy
# Processing Record 4 of Set 6 | lensk
# Processing Record 5 of Set 6 | mweka
# Processing Record 6 of Set 6 | portales
# Processing Record 7 of Set 6 | vardo
# Processing Record 8 of Set 6 | hithadhoo
# Processing Record 9 of Set 6 | venado tuerto
# Processing Record 10 of Set 6 | sao geraldo do araguaia
# Processing Record 11 of Set 6 | ponta do sol
# Processing Record 12 of Set 6 | candolim
# Processing Record 13 of Set 6 | yerbogachen
# Processing Record 14 of Set 6 | mount isa
# Processing Record 15 of Set 6 | outjo
# Processing Record 16 of Set 6 | puerto colombia
# Processing Record 17 of Set 6 | krasnogorsk
# Processing Record 18 of Set 6 | severo-kurilsk
# Processing Record 19 of Set 6 | qaqortoq
# Processing Record 20 of Set 6 | bandarbeyla
# Processing Record 21 of Set 6 | davila
# Processing Record 22 of Set 6 | nantucket
# Processing Record 23 of Set 6 | loandjili
# Processing Record 24 of Set 6 | ukiah
# Processing Record 25 of Set 6 | muros
# Processing Record 26 of Set 6 | ormara
# Processing Record 27 of Set 6 | duminichi
# Processing Record 28 of Set 6 | tromso
# Processing Record 29 of Set 6 | coxim
# Processing Record 30 of Set 6 | yirol
# City not found. Skipping...
# Processing Record 31 of Set 6 | palmer
# Processing Record 32 of Set 6 | barranca
# Processing Record 33 of Set 6 | rio gallegos
# Processing Record 34 of Set 6 | barrhead
# Processing Record 35 of Set 6 | katsuura
# Processing Record 36 of Set 6 | murindo
# Processing Record 37 of Set 6 | karatau
# Processing Record 38 of Set 6 | abalak
# Processing Record 39 of Set 6 | znamenskoye
# Processing Record 40 of Set 6 | provideniya
# Processing Record 41 of Set 6 | geraldton
# Processing Record 42 of Set 6 | cienaga de oro
# Processing Record 43 of Set 6 | isangel
# Processing Record 44 of Set 6 | ganta
# Processing Record 45 of Set 6 | koshurnikovo
# Processing Record 46 of Set 6 | sitka
# Processing Record 47 of Set 6 | korla
# Processing Record 48 of Set 6 | ligayan
# Processing Record 49 of Set 6 | avera
# Processing Record 50 of Set 6 | sao filipe
# Processing Record 1 of Set 7 | ust-ishim
# Processing Record 2 of Set 7 | wuan
# Processing Record 3 of Set 7 | eganville
# Processing Record 4 of Set 7 | mocuba
# Processing Record 5 of Set 7 | kyren
# Processing Record 6 of Set 7 | codrington
# Processing Record 7 of Set 7 | santa marta
# Processing Record 8 of Set 7 | kurilsk
# Processing Record 9 of Set 7 | paamiut
# Processing Record 10 of Set 7 | paita
# Processing Record 11 of Set 7 | zhuhai
# Processing Record 12 of Set 7 | southbridge
# Processing Record 13 of Set 7 | morant bay
# Processing Record 14 of Set 7 | king city
# Processing Record 15 of Set 7 | sandnessjoen
# Processing Record 16 of Set 7 | port elizabeth
# Processing Record 17 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 18 of Set 7 | axim
# Processing Record 19 of Set 7 | gallup
# Processing Record 20 of Set 7 | flin flon
# Processing Record 21 of Set 7 | chelno-vershiny
# Processing Record 22 of Set 7 | sahawar
# Processing Record 23 of Set 7 | atka
# City not found. Skipping...
# Processing Record 24 of Set 7 | caravelas
# Processing Record 25 of Set 7 | dongsheng
# Processing Record 26 of Set 7 | poum
# Processing Record 27 of Set 7 | chicago
# Processing Record 28 of Set 7 | richards bay
# Processing Record 29 of Set 7 | namibe
# Processing Record 30 of Set 7 | bangkalan
# Processing Record 31 of Set 7 | kloulklubed
# Processing Record 32 of Set 7 | jiuquan
# Processing Record 33 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 34 of Set 7 | cairns
# Processing Record 35 of Set 7 | campo verde
# Processing Record 36 of Set 7 | jiaozuo
# Processing Record 37 of Set 7 | reyes
# Processing Record 38 of Set 7 | kharp
# Processing Record 39 of Set 7 | andenes
# Processing Record 40 of Set 7 | burica
# City not found. Skipping...
# Processing Record 41 of Set 7 | ancud
# Processing Record 42 of Set 7 | les cayes
# Processing Record 43 of Set 7 | bowen
# Processing Record 44 of Set 7 | maputo
# Processing Record 45 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 46 of Set 7 | grand gaube
# Processing Record 47 of Set 7 | udachnyy
# Processing Record 48 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 7 | zhangye
# Processing Record 50 of Set 7 | castro
# Processing Record 1 of Set 8 | kushiro
# Processing Record 2 of Set 8 | beringovskiy
# Processing Record 3 of Set 8 | uvat
# Processing Record 4 of Set 8 | toribio
# Processing Record 5 of Set 8 | wukari
# Processing Record 6 of Set 8 | necochea
# Processing Record 7 of Set 8 | pisco
# Processing Record 8 of Set 8 | maralal
# Processing Record 9 of Set 8 | emba
# Processing Record 10 of Set 8 | naro-fominsk
# Processing Record 11 of Set 8 | coquimbo
# Processing Record 12 of Set 8 | debre birhan
# Processing Record 13 of Set 8 | mount gambier
# Processing Record 14 of Set 8 | visnes
# Processing Record 15 of Set 8 | bridgetown
# Processing Record 16 of Set 8 | clyde river
# Processing Record 17 of Set 8 | buraydah
# Processing Record 18 of Set 8 | kargapolye
# City not found. Skipping...
# Processing Record 19 of Set 8 | bilimbay
# Processing Record 20 of Set 8 | te anau
# Processing Record 21 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 22 of Set 8 | fairbanks
# Processing Record 23 of Set 8 | benghazi
# Processing Record 24 of Set 8 | pamplona
# Processing Record 25 of Set 8 | rabat
# Processing Record 26 of Set 8 | palimbang
# Processing Record 27 of Set 8 | margate
# Processing Record 28 of Set 8 | asau
# Processing Record 29 of Set 8 | port blair
# Processing Record 30 of Set 8 | shubarshi
# Processing Record 31 of Set 8 | cherskiy
# Processing Record 32 of Set 8 | portland
# Processing Record 33 of Set 8 | fallon
# Processing Record 34 of Set 8 | samarai
# Processing Record 35 of Set 8 | campoverde
# Processing Record 36 of Set 8 | gambita
# City not found. Skipping...
# Processing Record 37 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 38 of Set 8 | oktyabrskoye
# Processing Record 39 of Set 8 | guerrero negro
# Processing Record 40 of Set 8 | cayenne
# Processing Record 41 of Set 8 | anadyr
# Processing Record 42 of Set 8 | vila velha
# Processing Record 43 of Set 8 | acarau
# Processing Record 44 of Set 8 | talnakh
# Processing Record 45 of Set 8 | sinnamary
# Processing Record 46 of Set 8 | pueblo
# Processing Record 47 of Set 8 | vila franca do campo
# Processing Record 48 of Set 8 | chepareria
# Processing Record 49 of Set 8 | spearfish
# Processing Record 50 of Set 8 | smithers
# Processing Record 1 of Set 9 | hokitika
# Processing Record 2 of Set 9 | yumen
# Processing Record 3 of Set 9 | puerto el triunfo
# Processing Record 4 of Set 9 | gat
# Processing Record 5 of Set 9 | jujuy
# City not found. Skipping...
# Processing Record 6 of Set 9 | komsomolskiy
# Processing Record 7 of Set 9 | bilibino
# Processing Record 8 of Set 9 | hibbing
# Processing Record 9 of Set 9 | sfantu gheorghe
# Processing Record 10 of Set 9 | oktyabrskiy
# Processing Record 11 of Set 9 | porto santo
# Processing Record 12 of Set 9 | nuevo progreso
# Processing Record 13 of Set 9 | livingstone
# Processing Record 14 of Set 9 | surgut
# Processing Record 15 of Set 9 | thaton
# Processing Record 16 of Set 9 | sorland
# Processing Record 17 of Set 9 | tautira
# Processing Record 18 of Set 9 | bestobe
# Processing Record 19 of Set 9 | ak-dovurak
# Processing Record 20 of Set 9 | plettenberg bay
# Processing Record 21 of Set 9 | tres arroyos
# Processing Record 22 of Set 9 | coahuayana
# Processing Record 23 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 9 | priargunsk
# Processing Record 25 of Set 9 | hobyo
# Processing Record 26 of Set 9 | atherton
# Processing Record 27 of Set 9 | verkhnevilyuysk
# Processing Record 28 of Set 9 | makakilo city
# Processing Record 29 of Set 9 | bambanglipuro
# Processing Record 30 of Set 9 | kamennomostskoye
# Processing Record 31 of Set 9 | valparaiso
# Processing Record 32 of Set 9 | lewisville
# Processing Record 33 of Set 9 | zaysan
# Processing Record 34 of Set 9 | itaqui
# Processing Record 35 of Set 9 | nelson bay
# Processing Record 36 of Set 9 | bathsheba
# Processing Record 37 of Set 9 | darhan
# Processing Record 38 of Set 9 | karpathos
# Processing Record 39 of Set 9 | waingapu
# Processing Record 40 of Set 9 | talara
# Processing Record 41 of Set 9 | polson
# Processing Record 42 of Set 9 | vanavara
# Processing Record 43 of Set 9 | salinopolis
# Processing Record 44 of Set 9 | gogrial
# Processing Record 45 of Set 9 | westport
# Processing Record 46 of Set 9 | sanjwal
# Processing Record 47 of Set 9 | concepcion
# Processing Record 48 of Set 9 | san carlos de bariloche
# Processing Record 49 of Set 9 | kuching
# Processing Record 50 of Set 9 | los llanos de aridane
# Processing Record 1 of Set 10 | ibi
# Processing Record 2 of Set 10 | poronaysk
# Processing Record 3 of Set 10 | maumere
# Processing Record 4 of Set 10 | cabo rojo
# Processing Record 5 of Set 10 | yar-sale
# Processing Record 6 of Set 10 | flagstaff
# Processing Record 7 of Set 10 | tuatapere
# Processing Record 8 of Set 10 | hovd
# Processing Record 9 of Set 10 | lapeer
# Processing Record 10 of Set 10 | jabiru
# City not found. Skipping...
# Processing Record 11 of Set 10 | paucartambo
# City not found. Skipping...
# Processing Record 12 of Set 10 | canton
# Processing Record 13 of Set 10 | macusani
# Processing Record 14 of Set 10 | belize
# Processing Record 15 of Set 10 | mitsamiouli
# Processing Record 16 of Set 10 | suntar
# Processing Record 17 of Set 10 | hope
# Processing Record 18 of Set 10 | shieli
# Processing Record 19 of Set 10 | havelock
# Processing Record 20 of Set 10 | camacupa
# Processing Record 21 of Set 10 | quatre cocos
# Processing Record 22 of Set 10 | yeniseysk
# Processing Record 23 of Set 10 | shimoda
# Processing Record 24 of Set 10 | kerrville
# Processing Record 25 of Set 10 | vila
# Processing Record 26 of Set 10 | ugoofaaru
# Processing Record 27 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 10 | vanimo
# Processing Record 29 of Set 10 | paldiski
# Processing Record 30 of Set 10 | skovde
# City not found. Skipping...
# Processing Record 31 of Set 10 | bose
# Processing Record 32 of Set 10 | klobuck
# Processing Record 33 of Set 10 | afonso claudio
# Processing Record 34 of Set 10 | mathathane
# Processing Record 35 of Set 10 | dudinka
# Processing Record 36 of Set 10 | mezen
# Processing Record 37 of Set 10 | fohnsdorf
# Processing Record 38 of Set 10 | yanam
# Processing Record 39 of Set 10 | madang
# Processing Record 40 of Set 10 | miranorte
# City not found. Skipping...
# Processing Record 41 of Set 10 | baruun-urt
# Processing Record 42 of Set 10 | denia
# Processing Record 43 of Set 10 | jutai
# Processing Record 44 of Set 10 | lahaina
# Processing Record 45 of Set 10 | macklin
# Processing Record 46 of Set 10 | coihaique
# Processing Record 47 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 10 | lamu
# Processing Record 49 of Set 10 | inuvik
# Processing Record 50 of Set 10 | mapiripan
# Processing Record 1 of Set 11 | fukue
# Processing Record 2 of Set 11 | inhambane
# Processing Record 3 of Set 11 | angoche
# Processing Record 4 of Set 11 | nara
# Processing Record 5 of Set 11 | bloemfontein
# Processing Record 6 of Set 11 | nexo
# Processing Record 7 of Set 11 | sibolga
# Processing Record 8 of Set 11 | tazovskiy
# Processing Record 9 of Set 11 | delmenhorst
# Processing Record 10 of Set 11 | olafsvik
# Processing Record 11 of Set 11 | moratuwa
# Processing Record 12 of Set 11 | whitianga
# Processing Record 13 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 11 | imeni poliny osipenko
# Processing Record 15 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 11 | chilliwack
# Processing Record 17 of Set 11 | valenca do piaui
# Processing Record 18 of Set 11 | grindavik
# Processing Record 19 of Set 11 | bad bevensen
# Processing Record 20 of Set 11 | liverpool
# Processing Record 21 of Set 11 | bogovarovo
# Processing Record 22 of Set 11 | buala
# Processing Record 23 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 24 of Set 11 | vaitape
# Processing Record 25 of Set 11 | kangasala
# Processing Record 26 of Set 11 | ankang
# Processing Record 27 of Set 11 | pochutla
# Processing Record 28 of Set 11 | karlstad
# Processing Record 29 of Set 11 | alice springs
# Processing Record 30 of Set 11 | jataizinho
# Processing Record 31 of Set 11 | okato
# Processing Record 32 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 11 | ayan
# Processing Record 34 of Set 11 | finschhafen
# Processing Record 35 of Set 11 | pandan
# Processing Record 36 of Set 11 | dunedin
# Processing Record 37 of Set 11 | osakarovka
# Processing Record 38 of Set 11 | paramonga
# Processing Record 39 of Set 11 | russell
# Processing Record 40 of Set 11 | kuttanallur
# City not found. Skipping...
# Processing Record 41 of Set 11 | rio do sul
# Processing Record 42 of Set 11 | fort nelson
# Processing Record 43 of Set 11 | imbituba
# Processing Record 44 of Set 11 | fortuna
# Processing Record 45 of Set 11 | scicli
# Processing Record 46 of Set 11 | anchorage
# Processing Record 47 of Set 11 | safidon
# Processing Record 48 of Set 11 | rudnogorsk
# Processing Record 49 of Set 11 | waitati
# Processing Record 50 of Set 11 | zeitz
# Processing Record 1 of Set 12 | ryotsu
# Processing Record 2 of Set 12 | henties bay
# Processing Record 3 of Set 12 | banda aceh
# Processing Record 4 of Set 12 | soure
# Processing Record 5 of Set 12 | eseka
# Processing Record 6 of Set 12 | wanning
# Processing Record 7 of Set 12 | banska bystrica
# Processing Record 8 of Set 12 | nola
# Processing Record 9 of Set 12 | bouna
# Processing Record 10 of Set 12 | abu kamal
# Processing Record 11 of Set 12 | saldanha
# Processing Record 12 of Set 12 | elban
# Processing Record 13 of Set 12 | loreto
# Processing Record 14 of Set 12 | villazon
# Processing Record 15 of Set 12 | makurdi
# Processing Record 16 of Set 12 | hwange
# Processing Record 17 of Set 12 | mahbubabad
# Processing Record 18 of Set 12 | kisangani
# Processing Record 19 of Set 12 | tsumeb
# Processing Record 20 of Set 12 | sobolevo
# Processing Record 21 of Set 12 | vincennes
# Processing Record 22 of Set 12 | shalinskoye
# Processing Record 23 of Set 12 | siniscola
# Processing Record 24 of Set 12 | la rioja
# Processing Record 25 of Set 12 | evensk
# Processing Record 26 of Set 12 | san juan
# Processing Record 27 of Set 12 | erode
# Processing Record 28 of Set 12 | neiafu
# Processing Record 29 of Set 12 | sawtell
# Processing Record 30 of Set 12 | wad rawah
# Processing Record 31 of Set 12 | gizo
# Processing Record 32 of Set 12 | wajima
# Processing Record 33 of Set 12 | lata
# Processing Record 34 of Set 12 | voh
# Processing Record 35 of Set 12 | fare
# Processing Record 36 of Set 12 | dolores
# Processing Record 37 of Set 12 | kidal
# Processing Record 38 of Set 12 | winnemucca
# Processing Record 39 of Set 12 | adrasmon
# Processing Record 40 of Set 12 | gerash
# Processing Record 41 of Set 12 | tessalit
# Processing Record 42 of Set 12 | brownwood
# Processing Record 43 of Set 12 | amapa
# Processing Record 44 of Set 12 | encantado
# Processing Record 45 of Set 12 | navlya
# Processing Record 46 of Set 12 | padang
# Processing Record 47 of Set 12 | bururi
# Processing Record 48 of Set 12 | lebyazhye
# Processing Record 49 of Set 12 | newport
# Processing Record 50 of Set 12 | belousovka
# Processing Record 1 of Set 13 | pafos
# Processing Record 2 of Set 13 | chimore
# Processing Record 3 of Set 13 | franklin
# Processing Record 4 of Set 13 | marawi
# Processing Record 5 of Set 13 | tamazulapam
# City not found. Skipping...
# Processing Record 6 of Set 13 | urumqi
# Processing Record 7 of Set 13 | marienburg
# Processing Record 8 of Set 13 | riyadh
# Processing Record 9 of Set 13 | bubaque
# Processing Record 10 of Set 13 | orgun
# City not found. Skipping...
# Processing Record 11 of Set 13 | lompoc
# Processing Record 12 of Set 13 | guilin
# Processing Record 13 of Set 13 | platanos
# Processing Record 14 of Set 13 | kahului
# Processing Record 15 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 16 of Set 13 | tigil
# Processing Record 17 of Set 13 | isiro
# Processing Record 18 of Set 13 | boa vista
# Processing Record 19 of Set 13 | budhlada
# Processing Record 20 of Set 13 | litoral del san juan
# City not found. Skipping...
# Processing Record 21 of Set 13 | kralendijk
# Processing Record 22 of Set 13 | choix
# Processing Record 23 of Set 13 | nanuque
# Processing Record 24 of Set 13 | devyatka
# City not found. Skipping...
# Processing Record 25 of Set 13 | mutum
# Processing Record 26 of Set 13 | ardakan
# Processing Record 27 of Set 13 | ca mau
# Processing Record 28 of Set 13 | kemijarvi
# Processing Record 29 of Set 13 | rock sound
# Processing Record 30 of Set 13 | gushikawa
# Processing Record 31 of Set 13 | preobrazhenskaya
# City not found. Skipping...
# Processing Record 32 of Set 13 | bilma
# Processing Record 33 of Set 13 | yangjiang
# Processing Record 34 of Set 13 | zelenets
# Processing Record 35 of Set 13 | viksoyri
# City not found. Skipping...
# Processing Record 36 of Set 13 | erzin
# Processing Record 37 of Set 13 | camacha
# Processing Record 38 of Set 13 | asbe teferi
# Processing Record 39 of Set 13 | gotsu
# Processing Record 40 of Set 13 | kalmunai
# Processing Record 41 of Set 13 | le port
# Processing Record 42 of Set 13 | jacareacanga
# Processing Record 43 of Set 13 | lieksa
# Processing Record 44 of Set 13 | arman
# Processing Record 45 of Set 13 | nioki
# Processing Record 46 of Set 13 | sao domingos do maranhao
# Processing Record 47 of Set 13 | altamont
# Processing Record 48 of Set 13 | dingle
# Processing Record 49 of Set 13 | guicheng
# City not found. Skipping...
# Processing Record 50 of Set 13 | channel-port aux basques
# Processing Record 1 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 2 of Set 14 | kaeo
# Processing Record 3 of Set 14 | marsaxlokk
# Processing Record 4 of Set 14 | gaya
# Processing Record 5 of Set 14 | severo-yeniseyskiy
# Processing Record 6 of Set 14 | cockburn town
# Processing Record 7 of Set 14 | ishigaki
# Processing Record 8 of Set 14 | uyemskiy
# Processing Record 9 of Set 14 | pangody
# Processing Record 10 of Set 14 | diaz
# Processing Record 11 of Set 14 | santa maria
# Processing Record 12 of Set 14 | maniitsoq
# Processing Record 13 of Set 14 | byron bay
# Processing Record 14 of Set 14 | inderborskiy
# City not found. Skipping...
# Processing Record 15 of Set 14 | isa khel
# Processing Record 16 of Set 14 | antalaha
# Processing Record 17 of Set 14 | olinda
# Processing Record 18 of Set 14 | hegra
# Processing Record 19 of Set 14 | savalou
# Processing Record 20 of Set 14 | pelym
# Processing Record 21 of Set 14 | hirado
# Processing Record 22 of Set 14 | aginskoye
# Processing Record 23 of Set 14 | ostrogozhsk
# Processing Record 24 of Set 14 | along
# Processing Record 25 of Set 14 | noumea
# Processing Record 26 of Set 14 | ust-koksa
# Processing Record 27 of Set 14 | lagos
# Processing Record 28 of Set 14 | kitimat
# Processing Record 29 of Set 14 | baoding
# Processing Record 30 of Set 14 | hailar
# Processing Record 31 of Set 14 | portree
# Processing Record 32 of Set 14 | adwa
# Processing Record 33 of Set 14 | santa rosa del sur
# Processing Record 34 of Set 14 | lazaro cardenas
# Processing Record 35 of Set 14 | biloela
# Processing Record 36 of Set 14 | namtsy
# Processing Record 37 of Set 14 | homer
# Processing Record 38 of Set 14 | itarema
# Processing Record 39 of Set 14 | urusha
# Processing Record 40 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 14 | kashi
# Processing Record 42 of Set 14 | zhezkazgan
# Processing Record 43 of Set 14 | oussouye
# Processing Record 44 of Set 14 | bereda
# Processing Record 45 of Set 14 | lakhimpur
# Processing Record 46 of Set 14 | pemangkat
# Processing Record 47 of Set 14 | teknaf
# Processing Record 48 of Set 14 | la palma
# Processing Record 49 of Set 14 | ranong
# Processing Record 50 of Set 14 | rangoon
# Processing Record 1 of Set 15 | aksarka
# Processing Record 2 of Set 15 | skjervoy
# Processing Record 3 of Set 15 | changping
# Processing Record 4 of Set 15 | lakes entrance
# Processing Record 5 of Set 15 | witu
# Processing Record 6 of Set 15 | touros
# Processing Record 7 of Set 15 | sabaudia
# Processing Record 8 of Set 15 | nanton
# Processing Record 9 of Set 15 | luau
# Processing Record 10 of Set 15 | tual
# Processing Record 11 of Set 15 | souillac
# Processing Record 12 of Set 15 | rawson
# Processing Record 13 of Set 15 | ambovombe
# Processing Record 14 of Set 15 | panguipulli
# Processing Record 15 of Set 15 | ternate
# Processing Record 16 of Set 15 | devonport
# Processing Record 17 of Set 15 | deputatskiy
# Processing Record 18 of Set 15 | felidhoo
# City not found. Skipping...
# Processing Record 19 of Set 15 | watsa
# Processing Record 20 of Set 15 | mastic beach
# Processing Record 21 of Set 15 | skibbereen
# Processing Record 22 of Set 15 | aasiaat
# Processing Record 23 of Set 15 | key largo
# Processing Record 24 of Set 15 | goderich
# Processing Record 25 of Set 15 | bintulu
# Processing Record 26 of Set 15 | scottsburgh
# City not found. Skipping...
# Processing Record 27 of Set 15 | noyabrsk
# Processing Record 28 of Set 15 | harqalah
# Processing Record 29 of Set 15 | chimoio
# Processing Record 30 of Set 15 | bogo
# Processing Record 31 of Set 15 | teguldet
# Processing Record 32 of Set 15 | watertown
# Processing Record 33 of Set 15 | laje
# Processing Record 34 of Set 15 | manzanillo
# Processing Record 35 of Set 15 | jalu
# Processing Record 36 of Set 15 | muli
# Processing Record 37 of Set 15 | praia da vitoria
# Processing Record 38 of Set 15 | baracoa
# Processing Record 39 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 15 | nyurba
# Processing Record 41 of Set 15 | dubuque
# Processing Record 42 of Set 15 | halifax
# Processing Record 43 of Set 15 | kollam
# Processing Record 44 of Set 15 | mizdah
# Processing Record 45 of Set 15 | mahanoro
# Processing Record 46 of Set 15 | porto novo
# Processing Record 47 of Set 15 | tucuman
# Processing Record 48 of Set 15 | timizart
# Processing Record 49 of Set 15 | ucluelet
# Processing Record 50 of Set 15 | medea
# Processing Record 1 of Set 16 | kudahuvadhoo
# Processing Record 2 of Set 16 | alekseyevka
# Processing Record 3 of Set 16 | rorvik
# Processing Record 4 of Set 16 | nova petropolis
# Processing Record 5 of Set 16 | matay
# Processing Record 6 of Set 16 | okha
# Processing Record 7 of Set 16 | clarence town
# Processing Record 8 of Set 16 | great falls
# Processing Record 9 of Set 16 | chagoda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Aranos      NA -24.1333   19.1167     73.08        11           0
# 1  Puerto Ayora      EC  -0.7393  -90.3518     69.19        92          70
# 2       Kantang      TH   7.4054   99.5156     89.69        66          40
# 3    Georgetown      MY   5.4112  100.3354     89.53        72          20
# 4       Aklavik      CA  68.2191 -135.0107     29.23        88          98
# 5          Hilo      US  19.7297 -155.0900     84.27        91          75
# 6  Punta Arenas      CL -53.1500  -70.9167     42.91        61           0
# 7  Saint George      US  37.1041 -113.5841     60.53        48           1
# 8   Port Alfred      ZA -33.5906   26.8910     68.50        79         100
# 9        Torbay      CA  47.6666  -52.7314     46.58        95          90
#
#    Wind Speed Current Description
# 0       11.77           clear sky
# 1        6.78       broken clouds
# 2        2.30    scattered clouds
# 3        1.01          few clouds
# 4        8.12     overcast clouds
# 5        0.00       broken clouds
# 6        8.05           clear sky
# 7        1.01           clear sky
# 8       19.42     overcast clouds
# 9       14.97                mist

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label= False)
